# %%
print(1)
# Out:
# 1

# %%
print("ashu")
# Out:
# ashu

# %%
print("rohan")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pyspark
#       2 print("rohan")
#
# ModuleNotFoundError: No module named 'pyspark'
