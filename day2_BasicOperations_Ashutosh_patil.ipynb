# %%
str="ashutosh"
str
# Out:
# 'ashutosh'

# %%
str.capitalize()
# Out:
# 'Ashutosh'

# %%
str.casefold()
# Out:
# 'ashutosh'

# %%
str.endswith("h")
# Out:
# True

# %%
str.startswith("a")
# Out:
# True

# %%
name="ashutosh patil" 
result=name.split() #split the string by default space as delimeter
print(result)
# Out:
# ['ashutosh', 'patil']

# %%
name.count("s") #count the number of times character in string
# Out:
# 2

# %%
name.lower()
# Out:
# 'ashutosh patil'

# %%
name.upper()
# Out:
# 'ASHUTOSH PATIL'

# %%
name.title() #return pascal type data
# Out:
# 'Ashutosh Patil'

# %%
fruit=" apple   "
fruit.strip() #Removes white spaces
# Out:
# 'apple'

# %%
msg="hello world"
msg.replace("world","python")#replace word
# Out:
# 'hello python'

# %%
msg.find("world") #start with 0 index and w is at 6th index in string
# Out:
# 6

# %%
msg.index("h")
#Note: index() raises an error if substring not found; find() returns -1
# Out:
# 0

# %%
join=["a","b","c"]
",".join(["a","b","c"])
# Out:
# 'a,b,c'

# %%
deparment="hr"
deparment.isalpha()
# Out:
# True

# %%
marks="123afsd"
marks="123"
marks="bid data"
marks.isnumeric()
marks.isdigit()
marks.isalnum()
# Out:
# True

# %%
company="tcs"
company.encode()
b'tcs'.decode()
# Out:
# 'tcs'

# %%
lst=[10,20,30]
lst.append(40)
lst
# Out:
# [10, 20, 30, 40]

# %%
lst.insert(1,50)
lst
# Out:
# [10, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 20, 30, 40]

# %%
lst1=[10,20,30]
lst2=[40,50,60]
lst1.extend(lst2)
lst1
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
lst=["apple","banana","apple","mango","guava"]
lst.remove("apple")
lst
# Out:
# ['banana', 'apple', 'mango', 'guava']

# %%
#pop
lst=[10,20,30,40,50]
lst.pop()
lst
# Out:
# [10, 20, 30, 40]

# %%
lst.pop(1)
lst
# Out:
# [10]

# %%
lst.clear
lst
# Out:
# [10]

# %%
list=[10,20,30,4,5,80,10,20,10,20]
list.count(10)
list.sort()
list
# Out:
# [4, 5, 10, 10, 10, 20, 20, 20, 30, 80]

# %%
list.sort(reverse=True)
list
# Out:
# [4, 5, 10, 10, 10, 20, 20, 20, 30, 80]

# %%
list1=[1,2,3,4,5]
list1.reverse()
list1
# Out:
# [5, 4, 3, 2, 1]

# %%
a=[10,20,30]
b=a.copy()
b
# Out:
# [10, 20, 30]

# %%
#set
st={1,2,4,1,2,1,3}
st
# Out:
# {1, 2, 3, 4}

# %%
st.add(5)
st
# Out:
# {1, 2, 3, 4, 5}

# %%
st.update([6,7])
st
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
st.remove(1)#Removes element, gives error if not found
st
# Out:
# {2, 4, 5, 6, 7}

# %%
st.discard(8) #Removes element, no error if missing
st
# Out:
# {2, 4, 5, 6, 7}

# %%
st.pop()#Removes a random element
st
# Out:
# {5, 6, 7}

# %%
st.clear()
st
# Out:
# set()

# %%
a={1,2,3}
b={4,3,5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersection
a={1,2,3,5}
b={2,5,6}
print(a.intersection(b))
# Out:
# {2, 5}

# %%
#difference
a={1,2,3,4}
b={4,1}
print(a.difference(b))
# Out:
# {2, 3}

# %%
#symmetric_difference() ===> Elements NOT common

a={1,2,3,4}
b={4,1}
print(a.symmetric_difference(b))
# Out:
# {2, 3}

# %%
#Tuple
tp=(1,2,3,4,1,2,4,1)
tp.count(1)

tp.index(3)
# Out:
# 2

# %%
#Dictionary
thisdict = {
    "name": "ashutosh",
    "deparment": "IT",
    "year": 2023

}
print(thisdict)
thisdict.values()
thisdict.keys()

thisdict.update({"roll_no":101})
print(thisdict)
# Out:
# {'name': 'ashutosh', 'deparment': 'IT', 'year': 2023}
# {'name': 'ashutosh', 'deparment': 'IT', 'year': 2023, 'roll_no': 101}

# %%
a=thisdict.setdefault("department","cse")
print(a)
# Out:
# cse

# %%
x=thisdict.items()
print(x)
# Out:
# dict_items([('name', 'ashutosh'), ('deparment', 'IT'), ('year', 2023), ('roll_no', 101), ('department', 'cse')])

# %%
thisdict.pop("year") #Removes the element with the specified key
print(thisdict)
# Out:
# {'name': 'ashutosh', 'deparment': 'IT', 'roll_no': 101}

# %%
thisdict.popitem() #Removes the last inserted key-value pair
print(thisdict)
# Out:
# {'name': 'ashutosh'}
